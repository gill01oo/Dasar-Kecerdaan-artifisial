# %% [markdown]
# ### Soal: Pengaturan Letak Sensor di Area 2D
# Letakkan 5 sensor dalam area 10x10 sehingga saling berjauhan sejauh mungkin. Gunakan SA untuk meminimalkan total tumpang tindih antar sensor.
#
# $$
# \text{jarak}(a, b) = \sqrt{(x_1 - x_2)^2 + (y_1 - y_2)^2}
# $$

# %%
import random, math  # Import pustaka random dan math

# %%
def distance(a, b):
    # Tugas Anda: Nilai 20
    # Jarak Euclidean
    return math.sqrt((a[0] - b[0])**2 + (a[1] - b[1])**2)

# %%
def evaluate(sensors):
    overlap = 0
    min_distance = 2.0
    for i in range(len(sensors)):
        for j in range(i+1, len(sensors)):
            # Tugas Anda: Nilai 20
            # Hitung pasangan sensor terlalu dekat
            dist = distance(sensors[i], sensors[j])
            if dist < min_distance:
                overlap += 1
    return overlap

# %%
def simulated_annealing_sensors(T=100, alpha=0.95):
    sensors = [(random.uniform(0, 10), random.uniform(0, 10)) for _ in range(5)]  # Inisialisasi
    current_score = evaluate(sensors)
    while T > 0.01 and current_score > 0:
        new_sensors = sensors[:]
        i = random.randint(0, 4)
        new_sensors[i] = (random.uniform(0, 10), random.uniform(0, 10))
        # Tugas Anda: Nilai 40
        # Ubah posisi satu sensor
        # Evaluasi solusi baru
        new_score = evaluate(new_sensors)
        delta = new_score - current_score
        
        if delta < 0 or math.exp(-delta / T) > random.random():
            sensors = new_sensors
            current_score = new_score
            
        T *= alpha  # Pendinginan
    return sensors, current_score

# %%
# Tugas Anda: Nilai 20
# Jalankan algoritma
# Cetak hasil
for run in range(2):
    print(f"\n--- RUN {run + 1} ---")
    sensors, score = simulated_annealing_sensors(T=100, alpha=0.95)
    
    print(f"\nHasil Run {run + 1}:")
    print(f"Score akhir (overlap): {score}")
    print("Posisi sensor:")
    for i, sensor in enumerate(sensors):
        print(f"  Sensor {i+1}: ({sensor[0]:.3f}, {sensor[1]:.3f})")
# Out:
# --- RUN 1 ---
#
# Hasil Run 1:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.884, 6.263)
#   Sensor 2: (2.139, 7.208)
#   Sensor 3: (0.634, 9.306)
#   Sensor 4: (3.415, 4.725)
#   Sensor 5: (0.315, 2.211)
#
# --- RUN 2 ---
#
# Hasil Run 2:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.250, 9.477)
#   Sensor 2: (9.707, 4.907)
#   Sensor 3: (3.931, 2.456)
#   Sensor 4: (6.288, 4.259)
#   Sensor 5: (4.841, 5.858)
#
# --- RUN 3 ---
#
# Hasil Run 3:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.421, 7.392)
#   Sensor 2: (6.352, 8.896)
#   Sensor 3: (1.132, 1.205)
#   Sensor 4: (8.357, 7.794)
#   Sensor 5: (6.796, 0.004)
#
# --- RUN 4 ---
#
# Hasil Run 4:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.600, 3.527)
#   Sensor 2: (8.860, 8.046)
#   Sensor 3: (5.730, 9.657)
#   Sensor 4: (5.338, 2.118)
#   Sensor 5: (8.854, 2.535)
#
# --- RUN 5 ---
#
# Hasil Run 5:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.709, 9.803)
#   Sensor 2: (3.642, 3.506)
#   Sensor 3: (6.715, 4.837)
#   Sensor 4: (2.582, 0.858)
#   Sensor 5: (8.773, 2.501)
#
# --- RUN 6 ---
#
# Hasil Run 6:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.298, 5.918)
#   Sensor 2: (8.001, 6.165)
#   Sensor 3: (9.301, 8.973)
#   Sensor 4: (1.003, 3.475)
#   Sensor 5: (2.600, 6.160)
#
# --- RUN 7 ---
#
# Hasil Run 7:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.131, 0.057)
#   Sensor 2: (1.535, 5.647)
#   Sensor 3: (4.951, 1.051)
#   Sensor 4: (5.360, 3.458)
#   Sensor 5: (2.433, 7.625)
#
# --- RUN 8 ---
#
# Hasil Run 8:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.484, 0.717)
#   Sensor 2: (7.069, 2.524)
#   Sensor 3: (5.137, 8.079)
#   Sensor 4: (9.425, 4.995)
#   Sensor 5: (9.049, 9.128)
#
# --- RUN 9 ---
#
# Hasil Run 9:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.113, 3.861)
#   Sensor 2: (3.650, 1.381)
#   Sensor 3: (4.204, 5.295)
#   Sensor 4: (7.933, 5.886)
#   Sensor 5: (8.799, 0.490)
#
# --- RUN 10 ---
#
# Hasil Run 10:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.117, 8.539)
#   Sensor 2: (3.125, 4.555)
#   Sensor 3: (9.114, 8.062)
#   Sensor 4: (1.844, 2.178)
#   Sensor 5: (0.114, 9.313)
#
# --- RUN 11 ---
#
# Hasil Run 11:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.666, 8.522)
#   Sensor 2: (6.462, 3.542)
#   Sensor 3: (2.249, 9.663)
#   Sensor 4: (8.520, 5.921)
#   Sensor 5: (4.636, 2.321)
#
# --- RUN 12 ---
#
# Hasil Run 12:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.790, 5.365)
#   Sensor 2: (3.723, 0.058)
#   Sensor 3: (2.969, 7.570)
#   Sensor 4: (3.852, 5.604)
#   Sensor 5: (0.005, 8.259)
#
# --- RUN 13 ---
#
# Hasil Run 13:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.911, 8.473)
#   Sensor 2: (4.937, 8.291)
#   Sensor 3: (1.243, 6.929)
#   Sensor 4: (5.268, 4.688)
#   Sensor 5: (8.324, 2.479)
#
# --- RUN 14 ---
#
# Hasil Run 14:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.254, 4.348)
#   Sensor 2: (1.023, 4.214)
#   Sensor 3: (4.672, 9.994)
#   Sensor 4: (6.267, 0.704)
#   Sensor 5: (7.796, 8.262)
#
# --- RUN 15 ---
#
# Hasil Run 15:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.690, 7.273)
#   Sensor 2: (9.178, 8.573)
#   Sensor 3: (8.607, 1.737)
#   Sensor 4: (9.153, 5.615)
#   Sensor 5: (0.134, 6.936)
#
# --- RUN 16 ---
#
# Hasil Run 16:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.950, 9.669)
#   Sensor 2: (9.062, 2.002)
#   Sensor 3: (7.065, 2.925)
#   Sensor 4: (4.970, 6.941)
#   Sensor 5: (2.880, 6.869)
#
# --- RUN 17 ---
#
# Hasil Run 17:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.150, 6.439)
#   Sensor 2: (0.332, 7.375)
#   Sensor 3: (6.803, 3.170)
#   Sensor 4: (3.210, 3.492)
#   Sensor 5: (7.874, 1.313)
#
# --- RUN 18 ---
#
# Hasil Run 18:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.039, 9.671)
#   Sensor 2: (6.337, 9.697)
#   Sensor 3: (4.561, 7.753)
#   Sensor 4: (1.610, 6.843)
#   Sensor 5: (6.766, 3.348)
#
# --- RUN 19 ---
#
# Hasil Run 19:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.475, 7.290)
#   Sensor 2: (7.308, 1.001)
#   Sensor 3: (2.900, 5.805)
#   Sensor 4: (6.674, 5.358)
#   Sensor 5: (9.962, 6.361)
#
# --- RUN 20 ---
#
# Hasil Run 20:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.909, 1.865)
#   Sensor 2: (1.223, 0.146)
#   Sensor 3: (8.746, 7.165)
#   Sensor 4: (6.105, 8.959)
#   Sensor 5: (9.665, 1.352)
#
# --- RUN 21 ---
#
# Hasil Run 21:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.863, 5.660)
#   Sensor 2: (6.584, 4.712)
#   Sensor 3: (1.450, 9.921)
#   Sensor 4: (1.931, 3.093)
#   Sensor 5: (3.579, 0.563)
#
# --- RUN 22 ---
#
# Hasil Run 22:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.401, 2.219)
#   Sensor 2: (3.441, 0.084)
#   Sensor 3: (3.879, 7.647)
#   Sensor 4: (4.344, 2.133)
#   Sensor 5: (6.633, 5.371)
#
# --- RUN 23 ---
#
# Hasil Run 23:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.085, 2.480)
#   Sensor 2: (3.487, 8.732)
#   Sensor 3: (8.167, 6.802)
#   Sensor 4: (4.405, 0.342)
#   Sensor 5: (4.621, 3.325)
#
# --- RUN 24 ---
#
# Hasil Run 24:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.686, 9.689)
#   Sensor 2: (5.267, 6.029)
#   Sensor 3: (9.472, 7.719)
#   Sensor 4: (7.308, 6.137)
#   Sensor 5: (2.242, 7.013)
#
# --- RUN 25 ---
#
# Hasil Run 25:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.172, 9.539)
#   Sensor 2: (7.438, 6.051)
#   Sensor 3: (3.862, 9.817)
#   Sensor 4: (4.559, 6.582)
#   Sensor 5: (6.857, 2.555)
#
# --- RUN 26 ---
#
# Hasil Run 26:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.034, 1.573)
#   Sensor 2: (9.454, 9.114)
#   Sensor 3: (0.285, 0.222)
#   Sensor 4: (1.844, 3.499)
#   Sensor 5: (4.672, 5.088)
#
# --- RUN 27 ---
#
# Hasil Run 27:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.915, 3.002)
#   Sensor 2: (2.007, 3.856)
#   Sensor 3: (2.336, 8.603)
#   Sensor 4: (7.623, 6.611)
#   Sensor 5: (5.452, 5.618)
#
# --- RUN 28 ---
#
# Hasil Run 28:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.073, 7.653)
#   Sensor 2: (9.665, 6.157)
#   Sensor 3: (8.423, 3.423)
#   Sensor 4: (1.843, 7.112)
#   Sensor 5: (5.107, 5.684)
#
# --- RUN 29 ---
#
# Hasil Run 29:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.725, 7.917)
#   Sensor 2: (4.626, 0.941)
#   Sensor 3: (8.371, 1.727)
#   Sensor 4: (5.054, 4.588)
#   Sensor 5: (2.629, 4.683)
#
# --- RUN 30 ---
#
# Hasil Run 30:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.668, 3.522)
#   Sensor 2: (0.798, 0.293)
#   Sensor 3: (1.537, 2.314)
#   Sensor 4: (2.222, 5.397)
#   Sensor 5: (8.069, 9.114)
#
# --- RUN 31 ---
#
# Hasil Run 31:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.642, 6.204)
#   Sensor 2: (4.251, 2.371)
#   Sensor 3: (5.922, 3.617)
#   Sensor 4: (0.235, 9.007)
#   Sensor 5: (9.559, 3.877)
#
# --- RUN 32 ---
#
# Hasil Run 32:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.712, 9.457)
#   Sensor 2: (7.615, 7.880)
#   Sensor 3: (6.136, 2.057)
#   Sensor 4: (1.713, 3.582)
#   Sensor 5: (9.945, 3.518)
#
# --- RUN 33 ---
#
# Hasil Run 33:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.389, 7.341)
#   Sensor 2: (6.852, 1.300)
#   Sensor 3: (4.859, 3.048)
#   Sensor 4: (9.041, 9.408)
#   Sensor 5: (8.335, 7.095)
#
# --- RUN 34 ---
#
# Hasil Run 34:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.781, 9.446)
#   Sensor 2: (9.403, 0.698)
#   Sensor 3: (5.506, 1.960)
#   Sensor 4: (9.161, 9.947)
#   Sensor 5: (8.285, 5.034)
#
# --- RUN 35 ---
#
# Hasil Run 35:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.631, 3.163)
#   Sensor 2: (7.391, 8.954)
#   Sensor 3: (1.054, 2.879)
#   Sensor 4: (3.438, 1.544)
#   Sensor 5: (1.871, 4.894)
#
# --- RUN 36 ---
#
# Hasil Run 36:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.177, 4.034)
#   Sensor 2: (2.904, 1.778)
#   Sensor 3: (5.640, 5.287)
#   Sensor 4: (7.860, 1.767)
#   Sensor 5: (0.400, 5.642)
#
# --- RUN 37 ---
#
# Hasil Run 37:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.608, 0.184)
#   Sensor 2: (9.814, 1.958)
#   Sensor 3: (6.856, 0.883)
#   Sensor 4: (9.181, 3.936)
#   Sensor 5: (4.245, 2.963)
#
# --- RUN 38 ---
#
# Hasil Run 38:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.073, 1.166)
#   Sensor 2: (8.857, 8.859)
#   Sensor 3: (7.493, 0.903)
#   Sensor 4: (3.093, 3.240)
#   Sensor 5: (4.250, 9.966)
#
# --- RUN 39 ---
#
# Hasil Run 39:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.579, 4.437)
#   Sensor 2: (5.799, 5.251)
#   Sensor 3: (8.679, 8.163)
#   Sensor 4: (6.060, 2.633)
#   Sensor 5: (1.764, 1.234)
#
# --- RUN 40 ---
#
# Hasil Run 40:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.216, 2.982)
#   Sensor 2: (3.310, 8.367)
#   Sensor 3: (0.308, 7.477)
#   Sensor 4: (5.154, 4.422)
#   Sensor 5: (9.595, 0.088)
#
# --- RUN 41 ---
#
# Hasil Run 41:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.608, 6.655)
#   Sensor 2: (6.480, 7.508)
#   Sensor 3: (6.506, 4.541)
#   Sensor 4: (2.383, 8.894)
#   Sensor 5: (4.469, 1.639)
#
# --- RUN 42 ---
#
# Hasil Run 42:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.609, 2.422)
#   Sensor 2: (7.937, 4.188)
#   Sensor 3: (8.672, 9.107)
#   Sensor 4: (1.921, 8.146)
#   Sensor 5: (3.186, 3.026)
#
# --- RUN 43 ---
#
# Hasil Run 43:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.053, 4.513)
#   Sensor 2: (1.947, 1.092)
#   Sensor 3: (1.801, 4.606)
#   Sensor 4: (2.773, 7.798)
#   Sensor 5: (4.905, 4.608)
#
# --- RUN 44 ---
#
# Hasil Run 44:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.237, 1.423)
#   Sensor 2: (9.630, 8.373)
#   Sensor 3: (7.956, 0.748)
#   Sensor 4: (5.905, 5.611)
#   Sensor 5: (5.690, 8.624)
#
# --- RUN 45 ---
#
# Hasil Run 45:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.833, 9.846)
#   Sensor 2: (1.897, 8.907)
#   Sensor 3: (7.081, 7.553)
#   Sensor 4: (7.376, 0.948)
#   Sensor 5: (1.250, 5.259)
#
# --- RUN 46 ---
#
# Hasil Run 46:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.576, 4.952)
#   Sensor 2: (9.361, 8.038)
#   Sensor 3: (2.590, 8.136)
#   Sensor 4: (0.407, 4.598)
#   Sensor 5: (4.540, 2.442)
#
# --- RUN 47 ---
#
# Hasil Run 47:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.605, 7.209)
#   Sensor 2: (7.023, 9.218)
#   Sensor 3: (4.473, 3.713)
#   Sensor 4: (4.030, 9.604)
#   Sensor 5: (4.678, 1.413)
#
# --- RUN 48 ---
#
# Hasil Run 48:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.898, 8.502)
#   Sensor 2: (1.486, 5.063)
#   Sensor 3: (0.983, 2.287)
#   Sensor 4: (0.078, 7.067)
#   Sensor 5: (8.642, 5.971)
#
# --- RUN 49 ---
#
# Hasil Run 49:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.148, 8.757)
#   Sensor 2: (0.607, 1.520)
#   Sensor 3: (5.771, 5.408)
#   Sensor 4: (8.717, 3.878)
#   Sensor 5: (5.344, 2.687)
#
# --- RUN 50 ---
#
# Hasil Run 50:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.179, 9.759)
#   Sensor 2: (6.418, 8.729)
#   Sensor 3: (8.457, 8.921)
#   Sensor 4: (4.978, 4.922)
#   Sensor 5: (8.722, 1.092)
#
# --- RUN 51 ---
#
# Hasil Run 51:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.714, 7.656)
#   Sensor 2: (6.492, 6.395)
#   Sensor 3: (7.101, 3.714)
#   Sensor 4: (2.678, 8.635)
#   Sensor 5: (2.890, 6.127)
#
# --- RUN 52 ---
#
# Hasil Run 52:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.573, 0.924)
#   Sensor 2: (8.314, 6.748)
#   Sensor 3: (8.734, 1.808)
#   Sensor 4: (5.160, 3.305)
#   Sensor 5: (4.967, 6.532)
#
# --- RUN 53 ---
#
# Hasil Run 53:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.850, 6.578)
#   Sensor 2: (1.765, 7.785)
#   Sensor 3: (3.146, 2.685)
#   Sensor 4: (4.707, 6.938)
#   Sensor 5: (9.236, 3.196)
#
# --- RUN 54 ---
#
# Hasil Run 54:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.128, 1.090)
#   Sensor 2: (4.647, 6.829)
#   Sensor 3: (3.647, 9.544)
#   Sensor 4: (7.252, 7.115)
#   Sensor 5: (2.212, 0.793)
#
# --- RUN 55 ---
#
# Hasil Run 55:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.032, 4.384)
#   Sensor 2: (8.766, 1.741)
#   Sensor 3: (9.688, 9.436)
#   Sensor 4: (4.139, 9.944)
#   Sensor 5: (8.800, 6.835)
#
# --- RUN 56 ---
#
# Hasil Run 56:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.839, 5.964)
#   Sensor 2: (0.093, 6.735)
#   Sensor 3: (9.698, 2.064)
#   Sensor 4: (2.549, 5.949)
#   Sensor 5: (1.365, 8.353)
#
# --- RUN 57 ---
#
# Hasil Run 57:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.639, 6.341)
#   Sensor 2: (0.320, 6.741)
#   Sensor 3: (9.364, 9.893)
#   Sensor 4: (7.326, 2.350)
#   Sensor 5: (5.264, 8.080)
#
# --- RUN 58 ---
#
# Hasil Run 58:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.844, 1.345)
#   Sensor 2: (9.994, 7.271)
#   Sensor 3: (7.725, 6.438)
#   Sensor 4: (2.721, 7.234)
#   Sensor 5: (2.564, 4.512)
#
# --- RUN 59 ---
#
# Hasil Run 59:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.605, 5.834)
#   Sensor 2: (7.899, 8.483)
#   Sensor 3: (1.530, 7.107)
#   Sensor 4: (2.019, 2.817)
#   Sensor 5: (5.909, 4.857)
#
# --- RUN 60 ---
#
# Hasil Run 60:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.185, 8.120)
#   Sensor 2: (5.781, 8.136)
#   Sensor 3: (1.231, 0.881)
#   Sensor 4: (7.354, 2.793)
#   Sensor 5: (5.865, 0.461)
#
# --- RUN 61 ---
#
# Hasil Run 61:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.326, 3.964)
#   Sensor 2: (6.404, 9.335)
#   Sensor 3: (1.127, 9.683)
#   Sensor 4: (1.238, 2.030)
#   Sensor 5: (3.783, 0.665)
#
# --- RUN 62 ---
#
# Hasil Run 62:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.634, 1.097)
#   Sensor 2: (4.027, 6.320)
#   Sensor 3: (8.022, 4.076)
#   Sensor 4: (7.431, 7.982)
#   Sensor 5: (6.885, 2.013)
#
# --- RUN 63 ---
#
# Hasil Run 63:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.424, 9.389)
#   Sensor 2: (1.193, 0.764)
#   Sensor 3: (5.449, 4.287)
#   Sensor 4: (0.262, 7.912)
#   Sensor 5: (3.166, 6.184)
#
# --- RUN 64 ---
#
# Hasil Run 64:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.014, 0.949)
#   Sensor 2: (8.102, 0.032)
#   Sensor 3: (5.309, 8.776)
#   Sensor 4: (4.715, 5.864)
#   Sensor 5: (9.724, 2.603)
#
# --- RUN 65 ---
#
# Hasil Run 65:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.878, 9.358)
#   Sensor 2: (6.304, 6.900)
#   Sensor 3: (5.155, 1.672)
#   Sensor 4: (1.263, 7.114)
#   Sensor 5: (8.475, 0.004)
#
# --- RUN 66 ---
#
# Hasil Run 66:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.686, 2.517)
#   Sensor 2: (5.625, 6.886)
#   Sensor 3: (7.627, 9.349)
#   Sensor 4: (8.284, 2.032)
#   Sensor 5: (8.998, 7.739)
#
# --- RUN 67 ---
#
# Hasil Run 67:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.194, 8.694)
#   Sensor 2: (4.724, 4.814)
#   Sensor 3: (7.450, 1.298)
#   Sensor 4: (0.511, 1.193)
#   Sensor 5: (3.462, 0.445)
#
# --- RUN 68 ---
#
# Hasil Run 68:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.343, 4.216)
#   Sensor 2: (7.523, 3.334)
#   Sensor 3: (8.237, 0.829)
#   Sensor 4: (4.205, 2.201)
#   Sensor 5: (1.812, 3.133)
#
# --- RUN 69 ---
#
# Hasil Run 69:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.718, 4.761)
#   Sensor 2: (6.230, 1.196)
#   Sensor 3: (4.829, 9.080)
#   Sensor 4: (3.728, 5.596)
#   Sensor 5: (0.009, 3.546)
#
# --- RUN 70 ---
#
# Hasil Run 70:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.034, 1.797)
#   Sensor 2: (8.356, 8.559)
#   Sensor 3: (0.170, 5.000)
#   Sensor 4: (9.836, 5.733)
#   Sensor 5: (9.165, 2.464)
#
# --- RUN 71 ---
#
# Hasil Run 71:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.774, 9.913)
#   Sensor 2: (3.986, 0.111)
#   Sensor 3: (7.982, 2.467)
#   Sensor 4: (5.292, 8.275)
#   Sensor 5: (0.817, 7.635)
#
# --- RUN 72 ---
#
# Hasil Run 72:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.855, 5.534)
#   Sensor 2: (4.384, 0.928)
#   Sensor 3: (6.431, 3.357)
#   Sensor 4: (2.797, 2.926)
#   Sensor 5: (3.573, 4.909)
#
# --- RUN 73 ---
#
# Hasil Run 73:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.028, 2.228)
#   Sensor 2: (0.786, 6.408)
#   Sensor 3: (1.194, 8.866)
#   Sensor 4: (1.838, 3.346)
#   Sensor 5: (4.776, 4.103)
#
# --- RUN 74 ---
#
# Hasil Run 74:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.039, 2.843)
#   Sensor 2: (8.767, 6.098)
#   Sensor 3: (5.984, 8.037)
#   Sensor 4: (1.033, 9.151)
#   Sensor 5: (4.644, 5.820)
#
# --- RUN 75 ---
#
# Hasil Run 75:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.432, 6.635)
#   Sensor 2: (2.602, 0.043)
#   Sensor 3: (0.362, 9.046)
#   Sensor 4: (0.217, 4.873)
#   Sensor 5: (9.668, 8.111)
#
# --- RUN 76 ---
#
# Hasil Run 76:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.864, 6.440)
#   Sensor 2: (4.180, 9.046)
#   Sensor 3: (8.105, 0.740)
#   Sensor 4: (0.671, 3.919)
#   Sensor 5: (9.856, 2.610)
#
# --- RUN 77 ---
#
# Hasil Run 77:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.137, 3.762)
#   Sensor 2: (2.039, 9.770)
#   Sensor 3: (9.483, 4.812)
#   Sensor 4: (1.471, 7.842)
#   Sensor 5: (0.824, 2.396)
#
# --- RUN 78 ---
#
# Hasil Run 78:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.655, 0.947)
#   Sensor 2: (1.130, 2.479)
#   Sensor 3: (9.057, 6.145)
#   Sensor 4: (7.576, 4.215)
#   Sensor 5: (2.058, 4.564)
#
# --- RUN 79 ---
#
# Hasil Run 79:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.450, 2.990)
#   Sensor 2: (2.263, 1.433)
#   Sensor 3: (3.411, 6.775)
#   Sensor 4: (3.747, 9.221)
#   Sensor 5: (3.368, 3.666)
#
# --- RUN 80 ---
#
# Hasil Run 80:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.787, 6.647)
#   Sensor 2: (0.323, 6.618)
#   Sensor 3: (1.277, 9.887)
#   Sensor 4: (2.233, 0.087)
#   Sensor 5: (1.347, 3.975)
#
# --- RUN 81 ---
#
# Hasil Run 81:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.143, 5.811)
#   Sensor 2: (3.437, 1.773)
#   Sensor 3: (6.757, 9.831)
#   Sensor 4: (8.697, 6.000)
#   Sensor 5: (5.954, 1.022)
#
# --- RUN 82 ---
#
# Hasil Run 82:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.646, 8.553)
#   Sensor 2: (4.490, 0.045)
#   Sensor 3: (1.354, 2.161)
#   Sensor 4: (0.172, 8.693)
#   Sensor 5: (0.406, 5.914)
#
# --- RUN 83 ---
#
# Hasil Run 83:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.238, 1.956)
#   Sensor 2: (7.605, 7.998)
#   Sensor 3: (1.838, 3.925)
#   Sensor 4: (3.228, 8.213)
#   Sensor 5: (4.150, 5.529)
#
# --- RUN 84 ---
#
# Hasil Run 84:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.204, 4.116)
#   Sensor 2: (5.553, 7.691)
#   Sensor 3: (9.897, 8.282)
#   Sensor 4: (6.674, 3.994)
#   Sensor 5: (0.759, 9.852)
#
# --- RUN 85 ---
#
# Hasil Run 85:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.620, 3.592)
#   Sensor 2: (2.506, 0.434)
#   Sensor 3: (5.822, 6.232)
#   Sensor 4: (9.814, 9.823)
#   Sensor 5: (2.376, 6.500)
#
# --- RUN 86 ---
#
# Hasil Run 86:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.508, 6.493)
#   Sensor 2: (2.151, 6.006)
#   Sensor 3: (3.674, 2.979)
#   Sensor 4: (2.909, 1.020)
#   Sensor 5: (9.821, 6.859)
#
# --- RUN 87 ---
#
# Hasil Run 87:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.311, 5.013)
#   Sensor 2: (9.524, 7.150)
#   Sensor 3: (4.456, 1.867)
#   Sensor 4: (7.397, 2.426)
#   Sensor 5: (3.468, 8.127)
#
# --- RUN 88 ---
#
# Hasil Run 88:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.126, 9.994)
#   Sensor 2: (0.895, 6.469)
#   Sensor 3: (9.294, 4.547)
#   Sensor 4: (3.539, 6.066)
#   Sensor 5: (5.560, 3.001)
#
# --- RUN 89 ---
#
# Hasil Run 89:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.299, 0.818)
#   Sensor 2: (5.583, 7.622)
#   Sensor 3: (8.386, 5.779)
#   Sensor 4: (4.283, 2.150)
#   Sensor 5: (4.874, 4.693)
#
# --- RUN 90 ---
#
# Hasil Run 90:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.965, 7.242)
#   Sensor 2: (8.934, 9.248)
#   Sensor 3: (7.562, 2.018)
#   Sensor 4: (3.254, 5.149)
#   Sensor 5: (0.131, 6.707)
#
# --- RUN 91 ---
#
# Hasil Run 91:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.996, 3.197)
#   Sensor 2: (3.432, 8.806)
#   Sensor 3: (0.699, 2.493)
#   Sensor 4: (9.166, 7.948)
#   Sensor 5: (2.504, 4.623)
#
# --- RUN 92 ---
#
# Hasil Run 92:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.888, 8.661)
#   Sensor 2: (1.551, 1.807)
#   Sensor 3: (7.340, 4.801)
#   Sensor 4: (7.277, 1.046)
#   Sensor 5: (1.577, 3.911)
#
# --- RUN 93 ---
#
# Hasil Run 93:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.702, 9.914)
#   Sensor 2: (5.815, 7.650)
#   Sensor 3: (4.198, 6.239)
#   Sensor 4: (2.092, 7.356)
#   Sensor 5: (6.399, 4.272)
#
# --- RUN 94 ---
#
# Hasil Run 94:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.862, 9.169)
#   Sensor 2: (7.246, 2.047)
#   Sensor 3: (9.357, 1.593)
#   Sensor 4: (1.506, 9.737)
#   Sensor 5: (2.836, 5.921)
#
# --- RUN 95 ---
#
# Hasil Run 95:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.588, 1.320)
#   Sensor 2: (8.571, 3.316)
#   Sensor 3: (3.817, 9.103)
#   Sensor 4: (9.324, 5.272)
#   Sensor 5: (0.047, 5.432)
#
# --- RUN 96 ---
#
# Hasil Run 96:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.882, 0.487)
#   Sensor 2: (8.378, 1.950)
#   Sensor 3: (6.839, 0.029)
#   Sensor 4: (2.701, 9.534)
#   Sensor 5: (8.838, 8.720)
#
# --- RUN 97 ---
#
# Hasil Run 97:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.516, 1.908)
#   Sensor 2: (9.026, 9.115)
#   Sensor 3: (0.091, 9.833)
#   Sensor 4: (7.310, 7.377)
#   Sensor 5: (2.906, 0.664)
#
# --- RUN 98 ---
#
# Hasil Run 98:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.831, 5.609)
#   Sensor 2: (4.979, 2.275)
#   Sensor 3: (1.217, 8.560)
#   Sensor 4: (4.504, 8.933)
#   Sensor 5: (3.570, 5.658)
#
# --- RUN 99 ---
#
# Hasil Run 99:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.846, 6.282)
#   Sensor 2: (1.283, 8.252)
#   Sensor 3: (9.132, 1.238)
#   Sensor 4: (7.516, 5.336)
#   Sensor 5: (3.832, 2.269)
#
# --- RUN 100 ---
#
# Hasil Run 100:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.375, 8.519)
#   Sensor 2: (2.587, 6.548)
#   Sensor 3: (3.229, 0.645)
#   Sensor 4: (1.873, 8.858)
#   Sensor 5: (2.045, 4.546)
#
# --- RUN 101 ---
#
# Hasil Run 101:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.356, 1.340)
#   Sensor 2: (5.794, 9.535)
#   Sensor 3: (8.487, 2.010)
#   Sensor 4: (5.864, 5.807)
#   Sensor 5: (7.243, 7.992)
#
# --- RUN 102 ---
#
# Hasil Run 102:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.318, 2.587)
#   Sensor 2: (0.530, 5.724)
#   Sensor 3: (4.529, 7.574)
#   Sensor 4: (8.042, 9.183)
#   Sensor 5: (2.534, 9.279)
#
# --- RUN 103 ---
#
# Hasil Run 103:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.317, 7.325)
#   Sensor 2: (1.190, 1.100)
#   Sensor 3: (9.503, 8.857)
#   Sensor 4: (5.539, 0.912)
#   Sensor 5: (0.631, 4.342)
#
# --- RUN 104 ---
#
# Hasil Run 104:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.085, 8.754)
#   Sensor 2: (3.582, 4.665)
#   Sensor 3: (4.976, 8.407)
#   Sensor 4: (5.194, 3.140)
#   Sensor 5: (2.332, 2.043)
#
# --- RUN 105 ---
#
# Hasil Run 105:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.843, 7.380)
#   Sensor 2: (3.843, 1.879)
#   Sensor 3: (8.923, 3.801)
#   Sensor 4: (1.381, 5.700)
#   Sensor 5: (0.018, 8.898)
#
# --- RUN 106 ---
#
# Hasil Run 106:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.347, 1.329)
#   Sensor 2: (4.649, 9.735)
#   Sensor 3: (1.844, 0.682)
#   Sensor 4: (2.805, 8.725)
#   Sensor 5: (3.682, 5.801)
#
# --- RUN 107 ---
#
# Hasil Run 107:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.260, 2.214)
#   Sensor 2: (1.498, 8.351)
#   Sensor 3: (8.439, 1.840)
#   Sensor 4: (3.685, 4.911)
#   Sensor 5: (4.080, 1.574)
#
# --- RUN 108 ---
#
# Hasil Run 108:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.889, 1.473)
#   Sensor 2: (9.778, 7.484)
#   Sensor 3: (5.039, 9.625)
#   Sensor 4: (5.369, 7.169)
#   Sensor 5: (1.471, 4.960)
#
# --- RUN 109 ---
#
# Hasil Run 109:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.785, 9.629)
#   Sensor 2: (2.532, 1.975)
#   Sensor 3: (7.594, 1.296)
#   Sensor 4: (0.148, 3.960)
#   Sensor 5: (4.932, 3.519)
#
# --- RUN 110 ---
#
# Hasil Run 110:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.000, 9.961)
#   Sensor 2: (9.694, 0.688)
#   Sensor 3: (5.737, 6.604)
#   Sensor 4: (3.042, 7.859)
#   Sensor 5: (0.926, 6.527)
#
# --- RUN 111 ---
#
# Hasil Run 111:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.982, 6.049)
#   Sensor 2: (0.994, 1.109)
#   Sensor 3: (0.299, 3.161)
#   Sensor 4: (3.535, 4.027)
#   Sensor 5: (8.313, 0.407)
#
# --- RUN 112 ---
#
# Hasil Run 112:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.550, 9.127)
#   Sensor 2: (6.816, 6.936)
#   Sensor 3: (1.882, 0.149)
#   Sensor 4: (4.723, 2.077)
#   Sensor 5: (3.733, 8.312)
#
# --- RUN 113 ---
#
# Hasil Run 113:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.283, 4.274)
#   Sensor 2: (0.670, 9.901)
#   Sensor 3: (7.319, 9.765)
#   Sensor 4: (7.131, 5.842)
#   Sensor 5: (4.041, 9.566)
#
# --- RUN 114 ---
#
# Hasil Run 114:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.083, 2.718)
#   Sensor 2: (0.248, 8.512)
#   Sensor 3: (5.289, 1.662)
#   Sensor 4: (8.899, 9.143)
#   Sensor 5: (0.853, 4.260)
#
# --- RUN 115 ---
#
# Hasil Run 115:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.226, 0.543)
#   Sensor 2: (3.211, 2.923)
#   Sensor 3: (5.397, 6.622)
#   Sensor 4: (2.851, 5.800)
#   Sensor 5: (0.800, 1.845)
#
# --- RUN 116 ---
#
# Hasil Run 116:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.683, 8.592)
#   Sensor 2: (2.473, 1.275)
#   Sensor 3: (5.783, 3.260)
#   Sensor 4: (2.317, 9.810)
#   Sensor 5: (1.200, 4.684)
#
# --- RUN 117 ---
#
# Hasil Run 117:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.900, 9.129)
#   Sensor 2: (4.582, 9.432)
#   Sensor 3: (7.328, 0.835)
#   Sensor 4: (2.822, 2.398)
#   Sensor 5: (6.865, 7.178)
#
# --- RUN 118 ---
#
# Hasil Run 118:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.327, 4.279)
#   Sensor 2: (0.512, 0.573)
#   Sensor 3: (2.046, 7.572)
#   Sensor 4: (5.636, 2.050)
#   Sensor 5: (4.983, 6.149)
#
# --- RUN 119 ---
#
# Hasil Run 119:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.145, 2.862)
#   Sensor 2: (4.044, 9.741)
#   Sensor 3: (9.993, 4.494)
#   Sensor 4: (9.185, 6.587)
#   Sensor 5: (3.126, 4.739)
#
# --- RUN 120 ---
#
# Hasil Run 120:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.176, 6.320)
#   Sensor 2: (2.891, 7.815)
#   Sensor 3: (8.478, 7.556)
#   Sensor 4: (2.746, 2.886)
#   Sensor 5: (5.796, 8.303)
#
# --- RUN 121 ---
#
# Hasil Run 121:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.179, 0.782)
#   Sensor 2: (9.030, 2.345)
#   Sensor 3: (8.831, 0.306)
#   Sensor 4: (9.342, 6.515)
#   Sensor 5: (1.883, 5.170)
#
# --- RUN 122 ---
#
# Hasil Run 122:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.508, 8.500)
#   Sensor 2: (3.115, 5.320)
#   Sensor 3: (7.975, 2.343)
#   Sensor 4: (6.448, 9.595)
#   Sensor 5: (9.646, 9.392)
#
# --- RUN 123 ---
#
# Hasil Run 123:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.186, 3.472)
#   Sensor 2: (7.230, 4.288)
#   Sensor 3: (5.265, 8.122)
#   Sensor 4: (8.713, 8.122)
#   Sensor 5: (1.973, 9.867)
#
# --- RUN 124 ---
#
# Hasil Run 124:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.246, 5.037)
#   Sensor 2: (9.951, 0.750)
#   Sensor 3: (6.959, 2.806)
#   Sensor 4: (8.953, 5.039)
#   Sensor 5: (2.056, 0.228)
#
# --- RUN 125 ---
#
# Hasil Run 125:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.179, 2.954)
#   Sensor 2: (9.231, 6.379)
#   Sensor 3: (5.300, 6.396)
#   Sensor 4: (6.277, 8.197)
#   Sensor 5: (4.963, 3.770)
#
# --- RUN 126 ---
#
# Hasil Run 126:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.145, 7.734)
#   Sensor 2: (2.329, 2.989)
#   Sensor 3: (0.811, 9.284)
#   Sensor 4: (3.041, 1.062)
#   Sensor 5: (5.538, 1.387)
#
# --- RUN 127 ---
#
# Hasil Run 127:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.678, 7.470)
#   Sensor 2: (0.753, 6.801)
#   Sensor 3: (9.583, 0.982)
#   Sensor 4: (8.254, 6.188)
#   Sensor 5: (3.097, 9.847)
#
# --- RUN 128 ---
#
# Hasil Run 128:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.837, 7.486)
#   Sensor 2: (9.175, 5.228)
#   Sensor 3: (6.360, 7.369)
#   Sensor 4: (9.814, 2.042)
#   Sensor 5: (5.423, 4.149)
#
# --- RUN 129 ---
#
# Hasil Run 129:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.086, 7.832)
#   Sensor 2: (5.178, 1.300)
#   Sensor 3: (9.884, 4.440)
#   Sensor 4: (1.231, 3.848)
#   Sensor 5: (8.641, 6.726)
#
# --- RUN 130 ---
#
# Hasil Run 130:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.184, 7.790)
#   Sensor 2: (9.110, 3.725)
#   Sensor 3: (7.063, 2.400)
#   Sensor 4: (5.766, 5.887)
#   Sensor 5: (1.374, 3.368)
#
# --- RUN 131 ---
#
# Hasil Run 131:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.373, 4.451)
#   Sensor 2: (2.597, 0.563)
#   Sensor 3: (1.335, 7.794)
#   Sensor 4: (6.750, 3.444)
#   Sensor 5: (6.952, 0.392)
#
# --- RUN 132 ---
#
# Hasil Run 132:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.869, 7.084)
#   Sensor 2: (2.054, 1.313)
#   Sensor 3: (4.434, 3.237)
#   Sensor 4: (7.192, 6.005)
#   Sensor 5: (5.567, 0.865)
#
# --- RUN 133 ---
#
# Hasil Run 133:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.132, 2.830)
#   Sensor 2: (7.855, 0.972)
#   Sensor 3: (8.249, 3.655)
#   Sensor 4: (9.115, 8.413)
#   Sensor 5: (7.428, 9.638)
#
# --- RUN 134 ---
#
# Hasil Run 134:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.670, 6.636)
#   Sensor 2: (9.509, 0.948)
#   Sensor 3: (3.236, 2.126)
#   Sensor 4: (7.700, 7.917)
#   Sensor 5: (2.731, 8.880)
#
# --- RUN 135 ---
#
# Hasil Run 135:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.156, 2.575)
#   Sensor 2: (3.377, 2.525)
#   Sensor 3: (1.207, 0.282)
#   Sensor 4: (6.362, 0.935)
#   Sensor 5: (6.292, 6.641)
#
# --- RUN 136 ---
#
# Hasil Run 136:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.443, 5.215)
#   Sensor 2: (7.787, 7.117)
#   Sensor 3: (3.019, 3.055)
#   Sensor 4: (6.487, 9.917)
#   Sensor 5: (9.255, 8.556)
#
# --- RUN 137 ---
#
# Hasil Run 137:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.002, 3.521)
#   Sensor 2: (9.597, 6.887)
#   Sensor 3: (5.018, 2.340)
#   Sensor 4: (5.856, 8.508)
#   Sensor 5: (0.524, 9.545)
#
# --- RUN 138 ---
#
# Hasil Run 138:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.900, 4.872)
#   Sensor 2: (1.887, 5.564)
#   Sensor 3: (0.101, 7.203)
#   Sensor 4: (9.577, 4.249)
#   Sensor 5: (3.219, 2.263)
#
# --- RUN 139 ---
#
# Hasil Run 139:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.645, 3.243)
#   Sensor 2: (8.835, 6.089)
#   Sensor 3: (5.387, 8.427)
#   Sensor 4: (5.716, 1.922)
#   Sensor 5: (1.943, 9.079)
#
# --- RUN 140 ---
#
# Hasil Run 140:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.080, 7.144)
#   Sensor 2: (2.732, 9.292)
#   Sensor 3: (8.237, 2.246)
#   Sensor 4: (5.120, 2.591)
#   Sensor 5: (0.544, 9.453)
#
# --- RUN 141 ---
#
# Hasil Run 141:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.132, 0.979)
#   Sensor 2: (1.006, 6.768)
#   Sensor 3: (3.512, 8.744)
#   Sensor 4: (7.417, 5.387)
#   Sensor 5: (4.131, 1.381)
#
# --- RUN 142 ---
#
# Hasil Run 142:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.010, 6.241)
#   Sensor 2: (4.429, 2.531)
#   Sensor 3: (9.983, 8.155)
#   Sensor 4: (5.677, 8.979)
#   Sensor 5: (9.170, 3.416)
#
# --- RUN 143 ---
#
# Hasil Run 143:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.377, 9.621)
#   Sensor 2: (0.401, 6.944)
#   Sensor 3: (0.512, 2.052)
#   Sensor 4: (4.423, 3.634)
#   Sensor 5: (7.812, 5.088)
#
# --- RUN 144 ---
#
# Hasil Run 144:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.860, 9.264)
#   Sensor 2: (3.382, 1.753)
#   Sensor 3: (5.454, 5.487)
#   Sensor 4: (5.868, 2.769)
#   Sensor 5: (1.387, 4.536)
#
# --- RUN 145 ---
#
# Hasil Run 145:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.354, 1.711)
#   Sensor 2: (4.632, 6.663)
#   Sensor 3: (2.713, 4.975)
#   Sensor 4: (0.309, 5.752)
#   Sensor 5: (9.122, 8.554)
#
# --- RUN 146 ---
#
# Hasil Run 146:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.333, 1.322)
#   Sensor 2: (0.230, 8.336)
#   Sensor 3: (7.061, 8.522)
#   Sensor 4: (1.834, 0.730)
#   Sensor 5: (0.315, 2.814)
#
# --- RUN 147 ---
#
# Hasil Run 147:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.182, 1.045)
#   Sensor 2: (9.859, 0.463)
#   Sensor 3: (7.498, 4.892)
#   Sensor 4: (3.887, 3.061)
#   Sensor 5: (5.596, 9.017)
#
# --- RUN 148 ---
#
# Hasil Run 148:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.969, 5.581)
#   Sensor 2: (8.583, 6.602)
#   Sensor 3: (9.239, 9.959)
#   Sensor 4: (2.090, 7.031)
#   Sensor 5: (7.174, 1.642)
#
# --- RUN 149 ---
#
# Hasil Run 149:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.362, 0.308)
#   Sensor 2: (4.524, 6.929)
#   Sensor 3: (6.969, 6.173)
#   Sensor 4: (6.431, 8.681)
#   Sensor 5: (4.901, 0.895)
#
# --- RUN 150 ---
#
# Hasil Run 150:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.967, 6.746)
#   Sensor 2: (9.688, 3.167)
#   Sensor 3: (1.735, 9.951)
#   Sensor 4: (4.480, 4.870)
#   Sensor 5: (4.699, 9.104)
#
# --- RUN 151 ---
#
# Hasil Run 151:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.712, 8.687)
#   Sensor 2: (7.214, 4.904)
#   Sensor 3: (9.145, 1.247)
#   Sensor 4: (6.263, 2.320)
#   Sensor 5: (3.627, 6.147)
#
# --- RUN 152 ---
#
# Hasil Run 152:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.953, 0.964)
#   Sensor 2: (9.068, 5.275)
#   Sensor 3: (5.460, 9.349)
#   Sensor 4: (8.121, 8.104)
#   Sensor 5: (9.385, 0.286)
#
# --- RUN 153 ---
#
# Hasil Run 153:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.363, 4.606)
#   Sensor 2: (0.679, 0.349)
#   Sensor 3: (5.434, 5.384)
#   Sensor 4: (2.568, 8.743)
#   Sensor 5: (6.638, 0.133)
#
# --- RUN 154 ---
#
# Hasil Run 154:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.785, 0.547)
#   Sensor 2: (4.013, 2.633)
#   Sensor 3: (6.132, 4.401)
#   Sensor 4: (9.377, 3.329)
#   Sensor 5: (8.723, 5.477)
#
# --- RUN 155 ---
#
# Hasil Run 155:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.150, 8.136)
#   Sensor 2: (8.057, 9.484)
#   Sensor 3: (9.883, 6.833)
#   Sensor 4: (1.119, 4.512)
#   Sensor 5: (6.603, 3.185)
#
# --- RUN 156 ---
#
# Hasil Run 156:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.812, 7.229)
#   Sensor 2: (5.411, 4.162)
#   Sensor 3: (6.732, 1.962)
#   Sensor 4: (2.722, 9.510)
#   Sensor 5: (8.918, 0.659)
#
# --- RUN 157 ---
#
# Hasil Run 157:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.347, 0.339)
#   Sensor 2: (9.690, 4.134)
#   Sensor 3: (1.496, 6.622)
#   Sensor 4: (4.336, 8.137)
#   Sensor 5: (8.500, 0.077)
#
# --- RUN 158 ---
#
# Hasil Run 158:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.314, 4.977)
#   Sensor 2: (1.928, 7.262)
#   Sensor 3: (6.732, 7.271)
#   Sensor 4: (4.274, 0.227)
#   Sensor 5: (7.996, 3.580)
#
# --- RUN 159 ---
#
# Hasil Run 159:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.652, 9.035)
#   Sensor 2: (0.593, 6.237)
#   Sensor 3: (3.883, 2.914)
#   Sensor 4: (7.965, 1.317)
#   Sensor 5: (7.537, 3.771)
#
# --- RUN 160 ---
#
# Hasil Run 160:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.681, 5.287)
#   Sensor 2: (7.379, 3.555)
#   Sensor 3: (3.277, 1.947)
#   Sensor 4: (5.865, 1.984)
#   Sensor 5: (4.254, 9.346)
#
# --- RUN 161 ---
#
# Hasil Run 161:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.400, 1.822)
#   Sensor 2: (8.838, 6.019)
#   Sensor 3: (6.311, 5.000)
#   Sensor 4: (9.910, 0.209)
#   Sensor 5: (4.774, 6.695)
#
# --- RUN 162 ---
#
# Hasil Run 162:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.939, 0.031)
#   Sensor 2: (4.215, 6.406)
#   Sensor 3: (8.680, 4.122)
#   Sensor 4: (6.770, 3.510)
#   Sensor 5: (4.718, 2.391)
#
# --- RUN 163 ---
#
# Hasil Run 163:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.784, 5.949)
#   Sensor 2: (7.890, 4.579)
#   Sensor 3: (0.533, 8.074)
#   Sensor 4: (5.530, 3.845)
#   Sensor 5: (3.159, 4.130)
#
# --- RUN 164 ---
#
# Hasil Run 164:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.803, 7.129)
#   Sensor 2: (3.221, 4.000)
#   Sensor 3: (2.437, 6.897)
#   Sensor 4: (3.949, 1.375)
#   Sensor 5: (3.157, 9.183)
#
# --- RUN 165 ---
#
# Hasil Run 165:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.460, 1.220)
#   Sensor 2: (2.035, 2.227)
#   Sensor 3: (7.269, 4.378)
#   Sensor 4: (0.770, 3.910)
#   Sensor 5: (3.824, 6.725)
#
# --- RUN 166 ---
#
# Hasil Run 166:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.789, 9.366)
#   Sensor 2: (8.354, 2.587)
#   Sensor 3: (2.729, 8.395)
#   Sensor 4: (5.576, 6.097)
#   Sensor 5: (2.670, 4.196)
#
# --- RUN 167 ---
#
# Hasil Run 167:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.408, 4.022)
#   Sensor 2: (3.219, 8.357)
#   Sensor 3: (9.572, 6.900)
#   Sensor 4: (3.144, 0.694)
#   Sensor 5: (3.632, 3.985)
#
# --- RUN 168 ---
#
# Hasil Run 168:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.840, 0.024)
#   Sensor 2: (4.737, 2.900)
#   Sensor 3: (2.750, 3.878)
#   Sensor 4: (0.141, 7.661)
#   Sensor 5: (2.234, 9.065)
#
# --- RUN 169 ---
#
# Hasil Run 169:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.344, 0.427)
#   Sensor 2: (6.233, 0.917)
#   Sensor 3: (7.672, 4.835)
#   Sensor 4: (8.924, 9.861)
#   Sensor 5: (2.711, 0.025)
#
# --- RUN 170 ---
#
# Hasil Run 170:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (8.341, 2.352)
#   Sensor 2: (8.654, 6.789)
#   Sensor 3: (7.148, 5.203)
#   Sensor 4: (5.272, 2.284)
#   Sensor 5: (0.177, 4.148)
#
# --- RUN 171 ---
#
# Hasil Run 171:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.825, 7.379)
#   Sensor 2: (8.092, 3.790)
#   Sensor 3: (3.435, 4.994)
#   Sensor 4: (4.682, 2.525)
#   Sensor 5: (7.665, 1.773)
#
# --- RUN 172 ---
#
# Hasil Run 172:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.539, 0.131)
#   Sensor 2: (0.508, 9.585)
#   Sensor 3: (0.249, 0.607)
#   Sensor 4: (6.132, 4.963)
#   Sensor 5: (4.659, 9.125)
#
# --- RUN 173 ---
#
# Hasil Run 173:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.446, 6.796)
#   Sensor 2: (0.232, 0.016)
#   Sensor 3: (0.054, 6.317)
#   Sensor 4: (0.936, 8.366)
#   Sensor 5: (5.950, 2.471)
#
# --- RUN 174 ---
#
# Hasil Run 174:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.577, 1.693)
#   Sensor 2: (0.527, 4.734)
#   Sensor 3: (5.666, 4.215)
#   Sensor 4: (4.613, 7.028)
#   Sensor 5: (8.647, 1.446)
#
# --- RUN 175 ---
#
# Hasil Run 175:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.959, 6.876)
#   Sensor 2: (1.221, 0.790)
#   Sensor 3: (0.082, 6.603)
#   Sensor 4: (5.982, 8.784)
#   Sensor 5: (5.397, 5.491)
#
# --- RUN 176 ---
#
# Hasil Run 176:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.847, 2.274)
#   Sensor 2: (0.721, 1.036)
#   Sensor 3: (3.199, 5.794)
#   Sensor 4: (8.926, 6.984)
#   Sensor 5: (2.729, 8.735)
#
# --- RUN 177 ---
#
# Hasil Run 177:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.629, 5.371)
#   Sensor 2: (8.286, 2.940)
#   Sensor 3: (1.161, 2.308)
#   Sensor 4: (3.062, 7.732)
#   Sensor 5: (0.674, 8.878)
#
# --- RUN 178 ---
#
# Hasil Run 178:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.167, 0.018)
#   Sensor 2: (9.842, 5.124)
#   Sensor 3: (8.173, 7.668)
#   Sensor 4: (3.706, 4.536)
#   Sensor 5: (1.051, 7.639)
#
# --- RUN 179 ---
#
# Hasil Run 179:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (9.434, 4.361)
#   Sensor 2: (6.028, 7.737)
#   Sensor 3: (9.602, 8.861)
#   Sensor 4: (3.717, 1.046)
#   Sensor 5: (1.061, 4.973)
#
# --- RUN 180 ---
#
# Hasil Run 180:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.793, 8.204)
#   Sensor 2: (8.331, 7.542)
#   Sensor 3: (4.367, 1.593)
#   Sensor 4: (5.369, 3.603)
#   Sensor 5: (1.824, 3.616)
#
# --- RUN 181 ---
#
# Hasil Run 181:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.285, 8.924)
#   Sensor 2: (8.449, 9.356)
#   Sensor 3: (5.080, 8.144)
#   Sensor 4: (4.141, 0.798)
#   Sensor 5: (7.592, 0.181)
#
# --- RUN 182 ---
#
# Hasil Run 182:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.289, 2.442)
#   Sensor 2: (5.695, 6.907)
#   Sensor 3: (7.140, 3.078)
#   Sensor 4: (4.143, 4.652)
#   Sensor 5: (5.964, 0.829)
#
# --- RUN 183 ---
#
# Hasil Run 183:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.492, 2.258)
#   Sensor 2: (5.139, 0.086)
#   Sensor 3: (7.319, 9.298)
#   Sensor 4: (8.719, 6.589)
#   Sensor 5: (0.054, 7.382)
#
# --- RUN 184 ---
#
# Hasil Run 184:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.402, 2.316)
#   Sensor 2: (2.075, 4.426)
#   Sensor 3: (9.556, 5.200)
#   Sensor 4: (6.355, 4.754)
#   Sensor 5: (6.534, 1.798)
#
# --- RUN 185 ---
#
# Hasil Run 185:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.076, 8.890)
#   Sensor 2: (7.041, 2.435)
#   Sensor 3: (9.452, 0.010)
#   Sensor 4: (2.582, 2.397)
#   Sensor 5: (3.489, 6.803)
#
# --- RUN 186 ---
#
# Hasil Run 186:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.976, 0.321)
#   Sensor 2: (4.915, 5.838)
#   Sensor 3: (2.814, 3.115)
#   Sensor 4: (4.521, 1.515)
#   Sensor 5: (0.919, 2.348)
#
# --- RUN 187 ---
#
# Hasil Run 187:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (6.876, 3.529)
#   Sensor 2: (0.149, 5.219)
#   Sensor 3: (8.570, 6.724)
#   Sensor 4: (4.765, 1.434)
#   Sensor 5: (0.769, 1.708)
#
# --- RUN 188 ---
#
# Hasil Run 188:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.002, 1.877)
#   Sensor 2: (1.124, 7.005)
#   Sensor 3: (8.788, 2.877)
#   Sensor 4: (5.064, 7.036)
#   Sensor 5: (8.633, 5.278)
#
# --- RUN 189 ---
#
# Hasil Run 189:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (1.282, 1.808)
#   Sensor 2: (6.041, 1.699)
#   Sensor 3: (3.129, 3.706)
#   Sensor 4: (5.219, 6.813)
#   Sensor 5: (1.490, 9.602)
#
# --- RUN 190 ---
#
# Hasil Run 190:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.197, 4.379)
#   Sensor 2: (0.466, 8.643)
#   Sensor 3: (9.869, 7.108)
#   Sensor 4: (0.702, 0.286)
#   Sensor 5: (4.022, 8.319)
#
# --- RUN 191 ---
#
# Hasil Run 191:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.704, 2.335)
#   Sensor 2: (7.546, 6.696)
#   Sensor 3: (2.694, 4.428)
#   Sensor 4: (3.003, 8.203)
#   Sensor 5: (4.601, 0.116)
#
# --- RUN 192 ---
#
# Hasil Run 192:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.816, 2.629)
#   Sensor 2: (4.809, 4.053)
#   Sensor 3: (8.312, 4.589)
#   Sensor 4: (9.294, 1.076)
#   Sensor 5: (5.614, 9.669)
#
# --- RUN 193 ---
#
# Hasil Run 193:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.873, 3.241)
#   Sensor 2: (6.120, 8.774)
#   Sensor 3: (0.115, 8.140)
#   Sensor 4: (3.564, 8.270)
#   Sensor 5: (8.148, 8.190)
#
# --- RUN 194 ---
#
# Hasil Run 194:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.563, 5.016)
#   Sensor 2: (2.840, 2.612)
#   Sensor 3: (0.318, 7.368)
#   Sensor 4: (8.173, 7.473)
#   Sensor 5: (3.862, 9.150)
#
# --- RUN 195 ---
#
# Hasil Run 195:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (4.136, 9.782)
#   Sensor 2: (7.128, 8.380)
#   Sensor 3: (1.757, 9.624)
#   Sensor 4: (5.323, 4.427)
#   Sensor 5: (2.709, 3.095)
#
# --- RUN 196 ---
#
# Hasil Run 196:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (0.844, 4.281)
#   Sensor 2: (7.399, 3.495)
#   Sensor 3: (0.081, 0.259)
#   Sensor 4: (1.641, 9.230)
#   Sensor 5: (2.935, 4.622)
#
# --- RUN 197 ---
#
# Hasil Run 197:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (7.984, 7.698)
#   Sensor 2: (6.845, 4.507)
#   Sensor 3: (3.003, 3.417)
#   Sensor 4: (3.575, 9.362)
#   Sensor 5: (9.270, 4.160)
#
# --- RUN 198 ---
#
# Hasil Run 198:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (5.029, 0.956)
#   Sensor 2: (8.218, 4.908)
#   Sensor 3: (2.336, 1.392)
#   Sensor 4: (9.638, 3.104)
#   Sensor 5: (3.853, 5.099)
#
# --- RUN 199 ---
#
# Hasil Run 199:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (3.650, 8.507)
#   Sensor 2: (5.695, 2.132)
#   Sensor 3: (3.935, 0.383)
#   Sensor 4: (7.943, 9.123)
#   Sensor 5: (9.269, 2.849)
#
# --- RUN 200 ---
#
# Hasil Run 200:
# Score akhir (overlap): 0
# Posisi sensor:
#   Sensor 1: (2.275, 6.821)
#   Sensor 2: (0.621, 8.590)
#   Sensor 3: (9.684, 3.294)
#   Sensor 4: (8.602, 7.396)
#   Sensor 5: (0.242, 0.311)
